# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinmuhtiga/DasarPPLG-X-2627/blob/main/tugas_program_menghitung_segitiga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG BANGUN DATAR LUAS SEGITIGA
#
# nama kelompok : nova
#
#
# 1.   ucup
# 2.   alis
# 1.   List item
# 2.   List item

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile luassegitiga.cpp
# #include <iostream>
# using namespace std;
# int main ()
# {
#   int a,t,luas;
#   cout<< "program aplikasi menghitung luas segitiga"<<endl;
#   cout<<"masukkan alas segitiga"<<endl;
#   cin>>a;
#   cout<<"masukkan tinggi segitiga"<<endl;
#   cin>>t;
#   luas=0.5*a*t;
#   cout<<"luas segitiga adalah"<<luas<<endl;
#   return 0;
# }
# Out:
# Overwriting luassegitiga.cpp

# %%
# !g++ luassegitiga.cpp -o main

# %%
! ./main
# Out:
# program aplikasi menghitung luas segitiga
# masukkan alas segitiga
# 5
# masukkan tinggi segitiga
# 8
# luas segitiga adalah20
